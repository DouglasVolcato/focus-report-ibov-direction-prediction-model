# %%
pip install pandas sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.svm import SVC
import pandas as pd

# %%
data = pd.read_csv("data/csv/reports-data.csv")

# %%
data.head()
# Out:
#   releaseDate  stockDirection  ipcaData4Weeks  ipcaData1Week  ipcaDataToday  \
# 0  2024-03-11              -1            3.82           3.76           3.77
# 1  2024-03-18               1            3.82           3.77           3.79
# 2  2024-04-01              -1            3.76           3.75           3.75
# 3  2024-04-08               1            3.77           3.75           3.76
# 4  2024-04-15               1            3.79           3.76           3.71
#
#    pibData4Weeks  pibData1Week  pibDataToday  cambioData4Weeks  \
# 0           1.60          1.77          1.78              4.92
# 1           1.68          1.78          1.80              4.93
# 2           1.77          1.85          1.89              4.93
# 3           1.78          1.89          1.90              4.93
# 4           1.80          1.90          1.95              4.95
#
#    cambioData1Week  ...  investimentoDataToday  dividaLiquidaData4Weeks  \
# 0             4.93  ...                   67.0                    63.60
# 1             4.93  ...                   65.5                    63.60
# 2             4.95  ...                   65.0                    63.74
# 3             4.95  ...                   65.0                    63.64
# 4             4.95  ...                   67.0                    63.90
#
#    dividaLiquidaData1Week  dividaLiquidaDataToday  resPrimarioData4Weeks  \
# 0                   63.74                   63.64                  -0.80
# 1                   63.64                   63.90                  -0.80
# 2                   63.94                   63.85                  -0.78
# 3                   63.85                   63.85                  -0.79
# 4                   63.85                   63.77                  -0.75
#
#    resPrimarioData1Week  resPrimarioDataToday  resNominalData4Weeks  \
# 0                 -0.78                 -0.79                  -6.8
# 1                 -0.79                 -0.75                  -6.8
# 2                 -0.75                 -0.70                  -6.9
# 3                 -0.70                 -0.70                  -6.9
# 4                 -0.70                 -0.70                  -6.8
#
#    resNominalData1Week  resNominalDataToday
# 0                 -6.9                 -6.9
# 1                 -6.9                 -6.8
# 2                 -6.8                 -6.9
# 3                 -6.9                 -6.9
# 4                 -6.9                 -6.8
#
# [5 rows x 38 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   releaseDate              9 non-null      object
#  1   stockDirection           9 non-null      int64
#  2   ipcaData4Weeks           9 non-null      float64
#  3   ipcaData1Week            9 non-null      float64
#  4   ipcaDataToday            9 non-null      float64
#  5   pibData4Weeks            9 non-null      float64
#  6   pibData1Week             9 non-null      float64
#  7   pibDataToday             9 non-null      float64
#  8   cambioData4Weeks         9 non-null      float64
#  9   cambioData1Week          9 non-null      float64
#  10  cambioDataToday          9 non-null      float64
#  11  selicData4Weeks          9 non-null      float64
#  12  selicData1Week           9 non-null      float64
#  13  selicDataToday           9 non-null      float64
#  14  igpData4Weeks            9 non-null      float64
#  15  igpData1Week             9 non-null      float64
#  16  igpDataToday             9 non-null      float64
#  17  ipcaAdminData4Weeks      9 non-null      float64
#  18  ipcaAdminData1Week       9 non-null      float64
#  19  ipcaAdminDataToday       9 non-null      float64
#  20  contaCorrenteData4Weeks  9 non-null      float64
#  21  contaCorrenteData1Week   9 non-null      float64
#  22  contaCorrenteDataToday   9 non-null      float64
#  23  balComData4Weeks         9 non-null      float64
#  24  balComData1Week          9 non-null      float64
#  25  balComDataToday          9 non-null      float64
#  26  investimentoData4Weeks   9 non-null      float64
#  27  investimentoData1Week    9 non-null      float64
#  28  investimentoDataToday    9 non-null      float64
#  29  dividaLiquidaData4Weeks  9 non-null      float64
#  30  dividaLiquidaData1Week   9 non-null      float64
#  31  dividaLiquidaDataToday   9 non-null      float64
#  32  resPrimarioData4Weeks    9 non-null      float64
#  33  resPrimarioData1Week     9 non-null      float64
#  34  resPrimarioDataToday     9 non-null      float64
#  35  resNominalData4Weeks     9 non-null      float64
#  36  resNominalData1Week      9 non-null      float64
#  37  resNominalDataToday      9 non-null      float64
# dtypes: float64(36), int64(1), object(1)
# memory usage: 2.8+ KB

# %%
data = data.drop("releaseDate", axis=1)
features = data.drop("stockDirection", axis=1)
target = data["stockDirection"]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.5)

# %%
y_train.head()
# Out:
# 0   -1
# 4    1
# 2   -1
# 1    1
# Name: stockDirection, dtype: int64

# %%
X_train.head()
# Out:
#    ipcaData4Weeks  ipcaData1Week  ipcaDataToday  pibData4Weeks  pibData1Week  \
# 0            3.82           3.76           3.77           1.60          1.77
# 4            3.79           3.76           3.71           1.80          1.90
# 2            3.76           3.75           3.75           1.77          1.85
# 1            3.82           3.77           3.79           1.68          1.78
#
#    pibDataToday  cambioData4Weeks  cambioData1Week  cambioDataToday  \
# 0          1.78              4.92             4.93             4.93
# 4          1.95              4.95             4.95             4.97
# 2          1.89              4.93             4.95             4.95
# 1          1.80              4.93             4.93             4.95
#
#    selicData4Weeks  ...  investimentoDataToday  dividaLiquidaData4Weeks  \
# 0              9.0  ...                   67.0                    63.60
# 4              9.0  ...                   67.0                    63.90
# 2              9.0  ...                   65.0                    63.74
# 1              9.0  ...                   65.5                    63.60
#
#    dividaLiquidaData1Week  dividaLiquidaDataToday  resPrimarioData4Weeks  \
# 0                   63.74                   63.64                  -0.80
# 4                   63.85                   63.77                  -0.75
# 2                   63.94                   63.85                  -0.78
# 1                   63.64                   63.90                  -0.80
#
#    resPrimarioData1Week  resPrimarioDataToday  resNominalData4Weeks  \
# 0                 -0.78                 -0.79                  -6.8
# 4                 -0.70                 -0.70                  -6.8
# 2                 -0.75                 -0.70                  -6.9
# 1                 -0.79                 -0.75                  -6.8
#
#    resNominalData1Week  resNominalDataToday
# 0                 -6.9                 -6.9
# 4                 -6.9                 -6.8
# 2                 -6.8                 -6.9
# 1                 -6.9                 -6.8
#
# [4 rows x 36 columns]

# %%
def create_models():
    models = [
        ('RandomForest', RandomForestClassifier(n_estimators=100, max_depth=5)),
        ('SVC', SVC(kernel='linear')),
        ('KNN', KNeighborsClassifier(n_neighbors=4)),
        ('LogReg', LogisticRegression())
    ]
    return models

# %%
def train_and_evaluate(models, X_train, X_test, y_train, y_test):
    
    results = []
    
    for name, model in models:
        # training
        print(f"Training the model {name} with data from training set...")
        model.fit(X_train, y_train)

        # predictions with data from test set
        y_pred = model.predict(X_test)

        # calculation of metrics
        report = classification_report(y_test, y_pred)
        print("Classification Report\n", report)

        results.append([model, {'model': name, 'predictions': y_pred, 'report': report,}])           

    return results

# %%
models = create_models()
models
# Out:
# [('RandomForest', RandomForestClassifier(max_depth=5)),
#  ('SVC', SVC(kernel='linear')),
#  ('KNN', KNeighborsClassifier(n_neighbors=4)),
#  ('LogReg', LogisticRegression())]

# %%
results = train_and_evaluate(models, X_train, X_test, y_train, y_test)
results
# Out:
# Training the model RandomForest with data from training set...
# Classification Report
#                precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         1
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.60         5
#    macro avg       0.38      0.38      0.38         5
# weighted avg       0.60      0.60      0.60         5
#
# Training the model SVC with data from training set...
# Classification Report
#                precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         1
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.60         5
#    macro avg       0.38      0.38      0.38         5
# weighted avg       0.60      0.60      0.60         5
#
# Training the model KNN with data from training set...
# Classification Report
#                precision    recall  f1-score   support
#
#           -1       0.20      1.00      0.33         1
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.20         5
#    macro avg       0.10      0.50      0.17         5
# weighted avg       0.04      0.20      0.07         5
#
# Training the model LogReg with data from training set...
# Classification Report
#                precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#
#     accuracy                           0.80         5
#    macro avg       0.40      0.50      0.44         5
# weighted avg       0.64      0.80      0.71         5
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [[RandomForestClassifier(max_depth=5),
#   {'model': 'RandomForest',
#    'predictions': array([-1,  1,  1,  1,  1], dtype=int64),
#    'report': '              precision    recall  f1-score   support\n\n          -1       0.00      0.00      0.00         1\n           1       0.75      0.75      0.75         4\n\n    accuracy                           0.60         5\n   macro avg       0.38      0.38      0.38         5\nweighted avg       0.60      0.60      0.60         5\n'}],
#  [SVC(kernel='linear'),
#   {'model': 'SVC',
#    'predictions': array([ 1,  1,  1,  1, -1], dtype=int64),
#    'report': '              precision    recall  f1-score   support\n\n          -1       0.00      0.00      0.00         1\n           1       0.75      0.75      0.75         4\n\n    accuracy                           0.60         5\n   macro avg       0.38      0.38      0.38         5\nweighted avg       0.60      0.60      0.60         5\n'}],
#  [KNeighborsClassifier(n_neighbors=4),
#   {'model': 'KNN',
#    'predictions': array([-1, -1, -1, -1, -1], dtype=int64),
#    'report': '              precision    recall  f1-score   support\n\n          -1       0.20      1.00      0.33         1\n           1       0.00      0.00      0.00         4\n\n    accuracy                           0.20         5\n   macro avg       0.10      0.50      0.17         5\nweighted avg       0.04      0.20      0.07         5\n'}],
#  [LogisticRegression(),
#   {'model': 'LogReg',
#    'predictions': array([1, 1, 1, 1, 1], dtype=int64),
#    'report': '              precision    recall  f1-score   support\n\n          -1       0.00      0.00      0.00         1\n           1       0.80      1.00      0.89         4\n\n    accuracy                           0.80         5\n   macro avg       0.40      0.50      0.44         5\nweighted avg       0.64      0.80      0.71         5\n'}]]

# %%
pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("data/csv/reports-data.csv")
data.head()
# Out:
#   releaseDate  stockDirection  ipcaData4Weeks  ipcaData1Week  ipcaDataToday  \
# 0  2023-01-23               1            5.23           5.39           5.48
# 1  2023-02-27              -1            5.74           5.89           5.90
# 2  2023-03-06              -1            5.78           5.90           5.90
# 3  2023-03-13              -1            5.79           5.90           5.96
# 4  2023-04-03              -1            5.90           5.93           5.96
#
#    pibData4Weeks  pibData1Week  pibDataToday  cambioData4Weeks  \
# 0           0.79          0.77          0.79              5.27
# 1           0.80          0.80          0.84              5.25
# 2           0.79          0.84          0.85              5.25
# 3           0.76          0.85          0.89              5.25
# 4           0.85          0.90          0.90              5.25
#
#    cambioData1Week  ...  investimentoDataToday  dividaLiquidaData4Weeks  \
# ...

# %%
data = data.drop('releaseDate', axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   stockDirection           34 non-null     int64
#  1   ipcaData4Weeks           34 non-null     float64
#  2   ipcaData1Week            34 non-null     float64
#  3   ipcaDataToday            34 non-null     float64
#  4   pibData4Weeks            34 non-null     float64
#  5   pibData1Week             34 non-null     float64
#  6   pibDataToday             34 non-null     float64
#  7   cambioData4Weeks         34 non-null     float64
#  8   cambioData1Week          34 non-null     float64
#  9   cambioDataToday          34 non-null     float64
#  10  selicData4Weeks          34 non-null     float64
#  11  selicData1Week           34 non-null     float64
#  12  selicDataToday           34 non-null     float64
#  13  igpData4Weeks            34 non-null     float64
# ...

# %%
data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# ...

# %%
data.drop([
'pibData4Weeks',
'pibData1Week',
'pibDataToday',
'igpData4Weeks',
'igpData1Week',
'igpDataToday',
'investimentoData4Weeks',
'cambioData4Weeks',
'cambioData1Week',
'cambioDataToday',
'ipcaAdminData1Week',
'ipcaAdminDataToday',
'contaCorrenteData4Weeks',
'balComData4Weeks',
'balComDataToday',
'investimentoData1Week',
'investimentoDataToday',
'dividaLiquidaData4Weeks',
'dividaLiquidaData1Week',
'dividaLiquidaDataToday',
'resPrimarioData4Weeks',
'resPrimarioData1Week',
'resNominalData4Weeks',
'resNominalData1Week'
], axis=1).corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_95286_row0_col0, #T_95286_row1_col1, #T_95286_row2_col2, #T_95286_row2_col3, #T_95286_row3_col2, #T_95286_row3_col3, #T_95286_row4_col4, #T_95286_row5_col5, #T_95286_row5_col6, #T_95286_row6_col5, #T_95286_row6_col6, #T_95286_row7_col7, #T_95286_row8_col8, #T_95286_row9_col9, #T_95286_row10_col10, #T_95286_row11_col11, #T_95286_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_95286_row0_col1, #T_95286_row0_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_95286_row0_col2, #T_95286_row0_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_95286_row0_col3, #T_95286_row0_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_95286_row0_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_95286_row0_col8, #T_95286_row0_col12 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_95286_row0_col9 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# ...
